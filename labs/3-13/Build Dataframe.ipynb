# %% [markdown]
# # Scrape the XMLs

# %%
# Load modules
import pandas as pd
import xml.etree.cElementTree as ET #XML Parser
from lxml import etree #ElementTree and lxml allow us to parse the XML file.
import requests #make request to server
import time #pause loop
import itertools

# %%
# a request for the ids of all trials between 1754 and 1756
trials = requests.get('https://www.oldbaileyonline.org/obapi/ob?term0=fromdate_17540116&term1=todate_17561208&&start=0').json()

# iterate through manuscripts
for trial in trials['hits'][:10]:

    # build url
    url = 'http://www.oldbaileyonline.org/obapi/text?div={}'.format(trial)
        
    # get the response
    res = requests.get(url).text
        
    #create a file name
    fname = 'data/old-bailey-' + '-' + trial + '.xml'
        
    # save the file
    with open(fname, 'w') as f:
            f.write(res)

    # pause for a second so we don't overload their servers
    time.sleep(1)

# %% [markdown]
# # Function for Building Dataframe

# %%
def table_of_cases(xml_file_name):
    file = ET.ElementTree(file = xml_file_name)
    iterate = file.getiterator()
    i = 1
    table = pd.DataFrame()
    # Create an empty list to store text
    text_list = []
    for element in iterate:
        if element.tag == "interp":
            t = element.attrib['type']
            val = [element.attrib['value']]
            labels = list(table.columns.values)
            num = str(i)
            if t not in labels:
                table[t] = val
            elif t+num not in labels:
                table[t+num] = val
            elif t+num in labels:
                num = str(i+1)
                table[t+num] = val
        elif element.tag == 'p':
            # Use itertext to extract text from element
            text = ''.join(list(element.itertext()))
            # Replace \n (line breaks) and strip out leading numbers
            text = text.replace('\n', '').lstrip('0123456789.- ')
            # Remove excessive white spaces between words
            text = ' '.join(text.split())
            # Append to list
            text_list.append(text)
    # Add contents of list to column in dataframe
    table['text'] = ''.join(text_list)
    return table

# %% [markdown]
# # Loop Through XMLs and Build Dataframe

# %%
table = pd.DataFrame()
for i in trials['hits'][:10]:
    raw_data = 'data/old-bailey--'+ i +'.xml'
    data = table_of_cases(raw_data)
    table = table.append(data, ignore_index=True)
table
# Out:
#   collection      date  gender gender1 gender2      given     given1  \
# 0     BAILEY  17540116  female    male     NaN     Hannah    Richard
# 1     BAILEY  17540116    male  female    male      Peter       Mary
# 2     BAILEY  17540116  female    male  female      Sarah     Joseph
# 3     BAILEY  17540116    male  female    male     Joseph  Elizabeth
# 4     BAILEY  17540116    male    male     NaN       John     Thomas
# 5     BAILEY  17540116    male    male     NaN    William     Thomas
# 6     BAILEY  17540116    male    male    male    William   Nicholas
# 7     BAILEY  17540116  female    male     NaN       Anne       John
# 8     BAILEY  17540116    male    male    male     Robert       John
# 9     BAILEY  17540116  female  female  female  Elizabeth  Catherine
#
#       given2 offenceCategory offenceCategory1  ...     surname1  surname2  \
# 0        NaN           theft              NaN  ...        Beach       NaN
# 1     Joseph           theft              NaN  ...      Foreman    Sheers
# 2        Ann           theft              NaN  ...     Smithson  Smithson
# 3     Thomas           theft              NaN  ...     Kempster   Stevens
# 4        NaN           theft              NaN  ...   Fazakerley       NaN
# 5        NaN           theft              NaN  ...     Wetworth       NaN
# 6  Launcelot           theft              NaN  ...      Healing      Hide
# 7        NaN           theft              NaN  ...       Jervas       NaN
# 8    Abraham           theft        deception  ...        Thorp    Julian
# 9  Catharine           theft              NaN  ...        Davis     Davis
#
#                                                 text           type  \
# 0  Hannah Ash , spinster , was indicted for steal...            NaN
# 1  (M.) Peter Foreman and Mary his wife were indi...            NaN
# 2  (M.) Sarah Williams , spinster , was indicted ...  crimeLocation
# 3  (M.) Elizabeth wife of Joseph Kempster , was i...  crimeLocation
# 4  (M.) John Allen was indicted for stealing one ...            NaN
# 5  (M.) William Derter was indicted for stealing ...            NaN
# 6  (M.) William Ford was indicted for stealing on...  crimeLocation
# 7  (L.) Anne Beezley , spinster , was indicted fo...            NaN
# 8  Robert Barber was indicted for that he, togeth...            NaN
# 9  , 90. (M.) Elizabeth Eaton and Catherine Davis...  crimeLocation
#
#                        uri verdictCategory verdictCategory1  \
# 0  sessionsPapers/17540116          guilty              NaN
# 1  sessionsPapers/17540116          guilty              NaN
# 2  sessionsPapers/17540116          guilty              NaN
# 3  sessionsPapers/17540116          guilty              NaN
# 4  sessionsPapers/17540116       notGuilty              NaN
# 5  sessionsPapers/17540116       notGuilty              NaN
# 6  sessionsPapers/17540116          guilty              NaN
# 7  sessionsPapers/17540116          guilty              NaN
# 8  sessionsPapers/17540116          guilty        notGuilty
# 9  sessionsPapers/17540116          guilty              NaN
#
#   verdictSubcategory verdictSubcategory1  year
# 0      pleadedGuilty                 NaN  1754
# 1                NaN                 NaN  1754
# 2                NaN                 NaN  1754
# 3                NaN                 NaN  1754
# 4                NaN                 NaN  1754
# 5                NaN                 NaN  1754
# 6                NaN                 NaN  1754
# 7                NaN                 NaN  1754
# 8      pleadedGuilty          noEvidence  1754
# 9      lesserOffence                 NaN  1754
#
# [10 rows x 27 columns]
